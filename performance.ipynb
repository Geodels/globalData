# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

# %%
fp = "run_perf.csv"

# %%
data = pd.read_csv(fp, sep='\s+', parse_dates=['WALLTIME'])

# %%
#data.dtypes

# %%
data.plot(x='CPUS', y='WALLTIME', lw=3)
